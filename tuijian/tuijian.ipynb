# %%
import pandas as pd
import jieba
import jieba.posseg as pseg 
from sklearn import feature_extraction
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer  
from sklearn.metrics.pairwise import linear_kernel

ds = pd.read_excel('idxdfn.xlsx')

# %% [markdown]
# ## 对描述进行分词

# %%
import numpy as np
def get_rsc():
    '''return : 资源(dataframe)'''
    df = ds[['IND_COD','IND_NAME','BUSDFM']][0:102]
#     df = df[df.BUSDFM != np.nan]
#     df.sort_values(by='BUSDFM', ascending=False)
    df = df.fillna('')
    return df
#     指标定义与报表定义合并
#     merged_df = merged_df.append(df)
#     return merged_df


def fenci(rsc):
    '''
    对rsc中每个资源的BUSDFM进行中文分词
    rsc : 资源(dataframe)
    return 分词(list), 每个资源经过分词后的字符串(分词之间用空格分隔): 
    '''
    corpus = [] #语料库
    # for each rsc
    for index, row in rsc.iterrows():
        busdfm = row["BUSDFM"]
        words = pseg.cut(busdfm)
        # 把分好的词拼成一个字符串(中间空格分隔)
        words_str = ''# 分词后的字符串
        for word in words :
            words_str += word.word + ' '
        # 分词字符串加入列表
        corpus.append(words_str)
    return corpus


rsc = get_rsc()
print(rsc.shape)
print(rsc.iloc[99])
print(rsc.iloc[100])
corpus = fenci(rsc)
# Out:
# (102, 3)
# IND_COD                     B0222
# IND_NAME                      所得税
# BUSDFM      是指按规定从报告期损益中扣除的所得税费用。
# Name: 99, dtype: object
# IND_COD     B0223
# IND_NAME      净利润
# BUSDFM        NaN
# Name: 100, dtype: object
# IND_COD                   B0224
# IND_NAME                  拨备前利润
# BUSDFM      指扣除资产减值损失前所实现的利润总额。
# Name: 101, dtype: object
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-73f5a58940c5> in <module>()
#      37 print(rsc.iloc[100])
#      38 print(rsc.iloc[101])
# ---> 39 corpus = fenci(rsc)
#
# <ipython-input-6-73f5a58940c5> in fenci(rsc)
#      25         # 把分好的词拼成一个字符串(中间空格分隔)
#      26         words_str = ''# 分词后的字符串
# ---> 27         for word in words :
#      28             words_str += word.word + ' '
#      29         # 分词字符串加入列表
#
# ~\Anaconda3\lib\site-packages\jieba\posseg\__init__.py in cut(sentence, HMM)
#     279     global dt
#     280     if jieba.pool is None:
# --> 281         for w in dt.cut(sentence, HMM=HMM):
#     282             yield w
#     283     else:
#
# ~\Anaconda3\lib\site-packages\jieba\posseg\__init__.py in cut(self, sentence, HMM)
#     247
#     248     def cut(self, sentence, HMM=True):
# --> 249         for w in self.__cut_internal(sentence, HMM=HMM):
#     250             yield w
#     251
#
# ~\Anaconda3\lib\site-packages\jieba\posseg\__init__.py in __cut_internal(self, sentence, HMM)
#     215     def __cut_internal(self, sentence, HMM=True):
#     216         self.makesure_userdict_loaded()
# --> 217         sentence = strdecode(sentence)
#     218         blocks = re_han_internal.split(sentence)
#     219         if HMM:
#
# ~\Anaconda3\lib\site-packages\jieba\_compat.py in strdecode(sentence)
#      35     if not isinstance(sentence, text_type):
#      36         try:
# ---> 37             sentence = sentence.decode('utf-8')
#      38         except UnicodeDecodeError:
#      39             sentence = sentence.decode('gbk', 'ignore')
#
# AttributeError: 'float' object has no attribute 'decode'

# %% [markdown]
# ## 统计词权重(tf-idf值)

# %%
def get_word_weight(corpus):
    '''计算词的权重tf-idf
    corpus: 已分词的字符串list
    return: tf-idf矩阵, 每篇文章的每个词的权重
    '''
    vectorizer = CountVectorizer()
    # 得到词频矩阵：wc_matrix[i][j] 表示文本i中j词的词频
    wc_matrix = vectorizer.fit_transform(corpus)
    # 根据词频矩阵计算tf-idf矩阵: tfidf_matrix[i][j]表示i文本中j词的权重(tf-idf值)
    transformer = TfidfTransformer()
    tfidf_matrix = transformer.fit_transform(wc_matrix)
    # word_weight_to_excel(vectorizer.get_feature_names(), tfidf_matrix.toarray())
    return tfidf_matrix

def word_weight_to_excel(word, weight):
    '''
    权重矩阵输出到excel(调试用)
    word: 模型中的所有词语
    weight: 词权重数组
    '''
    rsc_name = rsc['IND_NAME']
    weight_df = pd.DataFrame(data=weight, columns=word, index=rsc_name)
    weight_df.to_excel('word_weight.xlsx')

word_weight = get_word_weight(corpus)
print(word_weight)
# Out:
# C:\Users\BO\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1059: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
#   (0, 149)	0.22292775596697956
#   (0, 159)	0.22292775596697956
#   (0, 193)	0.22292775596697956
#   (0, 285)	0.18435212210446172
#   (0, 68)	0.3484108063435447
#   (0, 25)	0.1457764882419439
#   (0, 16)	0.2739219701479302
#   (0, 195)	0.2739219701479302
#   (0, 233)	0.2739219701479302
#   (0, 91)	0.2739219701479302
#   (0, 228)	0.23534633628541232
#   (0, 257)	0.2739219701479302
#   (0, 265)	0.2739219701479302
#   (0, 141)	0.23534633628541232
#   (0, 268)	0.18435212210446172
#   (0, 108)	0.251356670896808
#   (0, 266)	0.12705084068998093
#   (1, 149)	0.24812189695755701
#   (1, 159)	0.24812189695755701
#   (1, 193)	0.24812189695755701
#   (1, 141)	0.2619439609386152
#   (1, 268)	0.205186644643234
#   (1, 276)	0.30487921325293826
#   (1, 170)	0.2619439609386152
#   (1, 94)	0.30487921325293826
#   :	:
#   (97, 173)	0.33421302689564936
#   (97, 8)	0.09260911145679135
#   (97, 245)	0.10735007026712066
#   (97, 166)	0.5367503513356033
#   (97, 267)	0.12839536285768158
#   (97, 92)	0.25679072571536316
#   (97, 188)	0.12162029190765518
#   (97, 161)	0.25679072571536316
#   (97, 45)	0.13712994846605955
#   (97, 103)	0.41138984539817863
#   (97, 252)	0.13712994846605955
#   (97, 227)	0.14944065544824248
#   (97, 32)	0.14944065544824248
#   (97, 38)	0.14944065544824248
#   (97, 281)	0.14944065544824248
#   (97, 165)	0.14944065544824248
#   (97, 298)	0.14944065544824248
#   (98, 115)	0.6761068036596086
#   (98, 63)	0.7368036305863234
#   (99, 160)	0.37769027292874263
#   (99, 164)	0.37769027292874263
#   (99, 154)	0.42585531452412545
#   (99, 167)	0.39873016977564374
#   (99, 267)	0.39873016977564374
#   (99, 151)	0.46408605881124537

# %% [markdown]
# ## 余弦相似度

# %%
import numpy as np

def get_similarities(tfidf_matrix):
    '''
    计算余弦相似度
    tfidf_matrix: tf-idf矩阵
    return: 余弦相似度矩阵
    '''
    cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
    return cosine_similarities


def get_tuijian_info(similarity_matrix, rsc):
    '''
    计算推荐信息
    方法：对rsc中的每条记录，从similarity_matrix中找出相似度最高的n个元素
    similarity_matrix: 相似度矩阵
    rsc: 
    return: 推荐信息(dataframe)
    '''
    result = pd.DataFrame()
    n = 3
    # for each 资源
    for idx, row in rsc.iterrows():
        rsccod = row['IND_COD']
        rscnam = row['IND_NAME']
        # 与本资源最相似的资源的索引列表:按相似度降序排列->得到排序后的索引值->对索引从第二个开始取
        similar_indices = np.argsort(-1*similarity_matrix[idx])[1:n+1]
        similar_items = [(rsccod, rscnam, rsc['IND_COD'][i], rsc['IND_NAME'][i], round(similarity_matrix[idx][i],4))
                         for i in similar_indices]
        similar_items_df = pd.DataFrame(data = similar_items, columns=['rsccod', 'rscnam', 'sim_rsccod','sim_rscnam','similarity'])
        result = result.append(similar_items_df)
    return result

cosine_similarities = get_similarities(tfidf_matrix)
tuijian_info = get_tuijian_info(cosine_similarities, rsc)
print(tuijian_info)
# Out:
#    rsc_cod            rsc_nam sim_rsccod         sim_rscnam  similarity
# 0    A0001               法人贷款      A0210              房地产贷款      0.3167
# 1    A0001               法人贷款      A0209            批发零售业贷款      0.2955
# 2    A0001               法人贷款      A0002             国际贸易融资      0.2654
# 0    A0002             国际贸易融资      A0001               法人贷款      0.2654
# 1    A0002             国际贸易融资      A0210              房地产贷款      0.2171
# 2    A0002             国际贸易融资      A0209            批发零售业贷款      0.2025
# 0    A0003             工资薪金支出      B0212               营业支出      0.1411
# 1    A0003             工资薪金支出      B0216             其他营业支出      0.1192
# 2    A0003             工资薪金支出      B0222                所得税      0.1048
# 0    A0021    本年累计新发放各项贷款加权利率      A0027    本年累计新发放个人贷款加权利率      0.8228
# 1    A0021    本年累计新发放各项贷款加权利率      A0029    本年累计新发放农户贷款加权利率      0.7151
# 2    A0021    本年累计新发放各项贷款加权利率      A0028    本年累计新发放三农贷款加权利率      0.6960
# 0    A0022    本年累计新发放实体贷款加权利率      A0031    当季累计新发放实体贷款加权利率      0.8450
# 1    A0022    本年累计新发放实体贷款加权利率      A0021    本年累计新发放各项贷款加权利率      0.6960
# 2    A0022    本年累计新发放实体贷款加权利率      A0027    本年累计新发放个人贷款加权利率      0.6754
# 0    A0023    本年累计新发放法人贷款加权利率      A0032    当季累计新发放法人贷款加权利率      0.8450
# 1    A0023    本年累计新发放法人贷款加权利率      A0021    本年累计新发放各项贷款加权利率      0.6960
# 2    A0023    本年累计新发放法人贷款加权利率      A0027    本年累计新发放个人贷款加权利率      0.6754
# 0    A0024  本年累计新发放大型企业贷款加权利率      A0033  当季累计新发放大型企业贷款加权利率      0.8634
# 1    A0024  本年累计新发放大型企业贷款加权利率      A0021    本年累计新发放各项贷款加权利率      0.6506
# 2    A0024  本年累计新发放大型企业贷款加权利率      A0027    本年累计新发放个人贷款加权利率      0.6314
# 0    A0025  本年累计新发放中型企业贷款加权利率      A0034  当季累计新发放中型企业贷款加权利率      0.8450
# 1    A0025  本年累计新发放中型企业贷款加权利率      A0021    本年累计新发放各项贷款加权利率      0.6960
# 2    A0025  本年累计新发放中型企业贷款加权利率      A0027    本年累计新发放个人贷款加权利率      0.6754
# 0    A0026  本年累计新发放小微企业贷款加权利率      A0035  当季累计新发放小微企业贷款加权利率      0.8634
# 1    A0026  本年累计新发放小微企业贷款加权利率      A0021    本年累计新发放各项贷款加权利率      0.6506
# 2    A0026  本年累计新发放小微企业贷款加权利率      A0027    本年累计新发放个人贷款加权利率      0.6314
# 0    A0027    本年累计新发放个人贷款加权利率      A0021    本年累计新发放各项贷款加权利率      0.8228
# 1    A0027    本年累计新发放个人贷款加权利率      A0036    当季累计新发放个人贷款加权利率      0.7890
# 2    A0027    本年累计新发放个人贷款加权利率      A0029    本年累计新发放农户贷款加权利率      0.6940
# ..     ...                ...        ...                ...         ...
# 0    B0213             业务及管理费      B0212               营业支出      0.3848
# 1    B0213             业务及管理费      B0210               汇兑损益      0.2319
# 2    B0213             业务及管理费      B0205          手续费及佣金净收入      0.2211
# 0    B0214            营业税金及附加      B0004       成本收入比（银监会口径）      0.3407
# 1    B0214            营业税金及附加      B0006            非利息收入比率      0.2461
# 2    B0214            营业税金及附加      B0218             营业外净收入      0.2324
# 0    B0215             资产减值损失      B0212               营业支出      0.1630
# 1    B0215             资产减值损失      B0216             其他营业支出      0.1319
# 2    B0215             资产减值损失      B0220              营业外支出      0.1081
# 0    B0216             其他营业支出      B0212               营业支出      0.6405
# 1    B0216             其他营业支出      B0220              营业外支出      0.3550
# 2    B0216             其他营业支出      B0004       成本收入比（银监会口径）      0.3210
# 0    B0217               营业利润      B0213             业务及管理费      0.1205
# 1    B0217               营业利润      B0202              利息净收入      0.0829
# 2    B0217               营业利润      B0210               汇兑损益      0.0765
# 0    B0218             营业外净收入      B0004       成本收入比（银监会口径）      0.5694
# 1    B0218             营业外净收入      B0006            非利息收入比率      0.5454
# 2    B0218             营业外净收入      B0214            营业税金及附加      0.2324
# 0    B0219              营业外收入      B0220              营业外支出      0.4272
# 1    B0219              营业外收入      B0211             其他业务收入      0.2924
# 2    B0219              营业外收入      B0210               汇兑损益      0.1696
# 0    B0220              营业外支出      B0219              营业外收入      0.4272
# 1    B0220              营业外支出      B0212               营业支出      0.3839
# 2    B0220              营业外支出      B0216             其他营业支出      0.3550
# 0    B0221             税前利润总额      B0210               汇兑损益      0.1954
# 1    B0221             税前利润总额      A0219              K宝客户数      0.0000
# 2    B0221             税前利润总额      A0218          电话银行及其他收入      0.0000
# 0    B0222                所得税      B0213             业务及管理费      0.1700
# 1    B0222                所得税      B0004       成本收入比（银监会口径）      0.1427
# 2    B0222                所得税      B0002           资本利润率ROE      0.1406
#
# [300 rows x 5 columns]

# %% [markdown]
# ## 入库

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

# 把 tuijian_info 入库
conn_str = 'mysql+pymysql://root:touzibtc123@localhost:3306/bmip?charset=utf8'
engine = create_engine(conn_str)
DBSession = sessionmaker(bind=engine)
session = DBSession()

sql = "delete from rsc_sim"
session.execute(sql)
for idx, row in tuijian_info.iterrows():
    sql = "insert into rsc_sim values('%s','%s','%s','%s',%f)" \
        % (row['rsc_cod'], row['rsc_nam'], row['sim_rsccod'], row['sim_rscnam'], row['similarity'])
    session.execute(sql)
session.commit()
session.close()
# Out:
# insert into rsc_sim values('A0001','法人贷款','A0210','房地产贷款',0.316700);
# insert into rsc_sim values('A0001','法人贷款','A0209','批发零售业贷款',0.295500);
# insert into rsc_sim values('A0001','法人贷款','A0002','国际贸易融资',0.265400);
# insert into rsc_sim values('A0002','国际贸易融资','A0001','法人贷款',0.265400);
# insert into rsc_sim values('A0002','国际贸易融资','A0210','房地产贷款',0.217100);
# insert into rsc_sim values('A0002','国际贸易融资','A0209','批发零售业贷款',0.202500);
# insert into rsc_sim values('A0003','工资薪金支出','B0212','营业支出',0.141100);
# insert into rsc_sim values('A0003','工资薪金支出','B0216','其他营业支出',0.119200);
# insert into rsc_sim values('A0003','工资薪金支出','B0222','所得税',0.104800);
# insert into rsc_sim values('A0021','本年累计新发放各项贷款加权利率','A0027','本年累计新发放个人贷款加权利率',0.822800);
# insert into rsc_sim values('A0021','本年累计新发放各项贷款加权利率','A0029','本年累计新发放农户贷款加权利率',0.715100);
# insert into rsc_sim values('A0021','本年累计新发放各项贷款加权利率','A0028','本年累计新发放三农贷款加权利率',0.696000);
# insert into rsc_sim values('A0022','本年累计新发放实体贷款加权利率','A0031','当季累计新发放实体贷款加权利率',0.845000);
# insert into rsc_sim values('A0022','本年累计新发放实体贷款加权利率','A0021','本年累计新发放各项贷款加权利率',0.696000);
# insert into rsc_sim values('A0022','本年累计新发放实体贷款加权利率','A0027','本年累计新发放个人贷款加权利率',0.675400);
# insert into rsc_sim values('A0023','本年累计新发放法人贷款加权利率','A0032','当季累计新发放法人贷款加权利率',0.845000);
# insert into rsc_sim values('A0023','本年累计新发放法人贷款加权利率','A0021','本年累计新发放各项贷款加权利率',0.696000);
# insert into rsc_sim values('A0023','本年累计新发放法人贷款加权利率','A0027','本年累计新发放个人贷款加权利率',0.675400);
# insert into rsc_sim values('A0024','本年累计新发放大型企业贷款加权利率','A0033','当季累计新发放大型企业贷款加权利率',0.863400);
# insert into rsc_sim values('A0024','本年累计新发放大型企业贷款加权利率','A0021','本年累计新发放各项贷款加权利率',0.650600);
# insert into rsc_sim values('A0024','本年累计新发放大型企业贷款加权利率','A0027','本年累计新发放个人贷款加权利率',0.631400);
# insert into rsc_sim values('A0025','本年累计新发放中型企业贷款加权利率','A0034','当季累计新发放中型企业贷款加权利率',0.845000);
# insert into rsc_sim values('A0025','本年累计新发放中型企业贷款加权利率','A0021','本年累计新发放各项贷款加权利率',0.696000);
# insert into rsc_sim values('A0025','本年累计新发放中型企业贷款加权利率','A0027','本年累计新发放个人贷款加权利率',0.675400);
# insert into rsc_sim values('A0026','本年累计新发放小微企业贷款加权利率','A0035','当季累计新发放小微企业贷款加权利率',0.863400);
# insert into rsc_sim values('A0026','本年累计新发放小微企业贷款加权利率','A0021','本年累计新发放各项贷款加权利率',0.650600);
# insert into rsc_sim values('A0026','本年累计新发放小微企业贷款加权利率','A0027','本年累计新发放个人贷款加权利率',0.631400);
# insert into rsc_sim values('A0027','本年累计新发放个人贷款加权利率','A0021','本年累计新发放各项贷款加权利率',0.822800);
# insert into rsc_sim values('A0027','本年累计新发放个人贷款加权利率','A0036','当季累计新发放个人贷款加权利率',0.789000);
# insert into rsc_sim values('A0027','本年累计新发放个人贷款加权利率','A0029','本年累计新发放农户贷款加权利率',0.694000);
# insert into rsc_sim values('A0028','本年累计新发放三农贷款加权利率','A0037','当季累计新发放三农贷款加权利率',0.845000);
# insert into rsc_sim values('A0028','本年累计新发放三农贷款加权利率','A0021','本年累计新发放各项贷款加权利率',0.696000);
# insert into rsc_sim values('A0028','本年累计新发放三农贷款加权利率','A0027','本年累计新发放个人贷款加权利率',0.675400);
# insert into rsc_sim values('A0029','本年累计新发放农户贷款加权利率','A0038','当季累计新发放农户贷款加权利率',0.837000);
# insert into rsc_sim values('A0029','本年累计新发放农户贷款加权利率','A0030','当季累计新发放各项贷款加权利率',0.837000);
# insert into rsc_sim values('A0029','本年累计新发放农户贷款加权利率','A0021','本年累计新发放各项贷款加权利率',0.715100);
# insert into rsc_sim values('A0030','当季累计新发放各项贷款加权利率','A0030','当季累计新发放各项贷款加权利率',1.000000);
# insert into rsc_sim values('A0030','当季累计新发放各项贷款加权利率','A0029','本年累计新发放农户贷款加权利率',0.837000);
# insert into rsc_sim values('A0030','当季累计新发放各项贷款加权利率','A0036','当季累计新发放个人贷款加权利率',0.734300);
# insert into rsc_sim values('A0031','当季累计新发放实体贷款加权利率','A0022','本年累计新发放实体贷款加权利率',0.845000);
# insert into rsc_sim values('A0031','当季累计新发放实体贷款加权利率','A0036','当季累计新发放个人贷款加权利率',0.716900);
# insert into rsc_sim values('A0031','当季累计新发放实体贷款加权利率','A0038','当季累计新发放农户贷款加权利率',0.635000);
# insert into rsc_sim values('A0032','当季累计新发放法人贷款加权利率','A0023','本年累计新发放法人贷款加权利率',0.845000);
# insert into rsc_sim values('A0032','当季累计新发放法人贷款加权利率','A0036','当季累计新发放个人贷款加权利率',0.716900);
# insert into rsc_sim values('A0032','当季累计新发放法人贷款加权利率','A0038','当季累计新发放农户贷款加权利率',0.635000);
# insert into rsc_sim values('A0033','当季累计新发放大型企业贷款加权利率','A0024','本年累计新发放大型企业贷款加权利率',0.863400);
# insert into rsc_sim values('A0033','当季累计新发放大型企业贷款加权利率','A0036','当季累计新发放个人贷款加权利率',0.675100);
# insert into rsc_sim values('A0033','当季累计新发放大型企业贷款加权利率','A0035','当季累计新发放小微企业贷款加权利率',0.663000);
# insert into rsc_sim values('A0034','当季累计新发放中型企业贷款加权利率','A0025','本年累计新发放中型企业贷款加权利率',0.845000);
# insert into rsc_sim values('A0034','当季累计新发放中型企业贷款加权利率','A0036','当季累计新发放个人贷款加权利率',0.716900);
# insert into rsc_sim values('A0034','当季累计新发放中型企业贷款加权利率','A0030','当季累计新发放各项贷款加权利率',0.635000);
# insert into rsc_sim values('A0035','当季累计新发放小微企业贷款加权利率','A0026','本年累计新发放小微企业贷款加权利率',0.863400);
# insert into rsc_sim values('A0035','当季累计新发放小微企业贷款加权利率','A0036','当季累计新发放个人贷款加权利率',0.675100);
# insert into rsc_sim values('A0035','当季累计新发放小微企业贷款加权利率','A0033','当季累计新发放大型企业贷款加权利率',0.663000);
# insert into rsc_sim values('A0036','当季累计新发放个人贷款加权利率','A0027','本年累计新发放个人贷款加权利率',0.789000);
# insert into rsc_sim values('A0036','当季累计新发放个人贷款加权利率','A0038','当季累计新发放农户贷款加权利率',0.734300);
# insert into rsc_sim values('A0036','当季累计新发放个人贷款加权利率','A0030','当季累计新发放各项贷款加权利率',0.734300);
# insert into rsc_sim values('A0037','当季累计新发放三农贷款加权利率','A0028','本年累计新发放三农贷款加权利率',0.845000);
# insert into rsc_sim values('A0037','当季累计新发放三农贷款加权利率','A0036','当季累计新发放个人贷款加权利率',0.716900);
# insert into rsc_sim values('A0037','当季累计新发放三农贷款加权利率','A0030','当季累计新发放各项贷款加权利率',0.635000);
# insert into rsc_sim values('A0038','当季累计新发放农户贷款加权利率','A0030','当季累计新发放各项贷款加权利率',1.000000);
# insert into rsc_sim values('A0038','当季累计新发放农户贷款加权利率','A0029','本年累计新发放农户贷款加权利率',0.837000);
# insert into rsc_sim values('A0038','当季累计新发放农户贷款加权利率','A0036','当季累计新发放个人贷款加权利率',0.734300);
# insert into rsc_sim values('A0039','个人网银客户数','A0219','K宝客户数',0.742700);
# insert into rsc_sim values('A0039','个人网银客户数','A0220','K令客户数',0.742700);
# insert into rsc_sim values('A0039','个人网银客户数','A0046','企业网银客户数',0.726600);
# insert into rsc_sim values('A0040','掌上银行客户数','A0041','掌上银行客户端客户数',0.735000);
# insert into rsc_sim values('A0040','掌上银行客户数','A0203','掌上银行活跃客户数计划完成率',0.573300);
# insert into rsc_sim values('A0040','掌上银行客户数','A0057','个人电话银行客户数',0.562800);
# insert into rsc_sim values('A0041','掌上银行客户端客户数','A0040','掌上银行客户数',0.735000);
# insert into rsc_sim values('A0041','掌上银行客户端客户数','A0093','掌上银行动户率',0.491900);
# insert into rsc_sim values('A0041','掌上银行客户端客户数','A0203','掌上银行活跃客户数计划完成率',0.474700);
# insert into rsc_sim values('A0042','个人消息服务客户数','A0047','企业消息服务客户数',0.853400);
# insert into rsc_sim values('A0042','个人消息服务客户数','A0043','个人消息服务账户数',0.785500);
# insert into rsc_sim values('A0042','个人消息服务客户数','A0048','企业消息服务账户数',0.659200);
# insert into rsc_sim values('A0043','个人消息服务账户数','A0048','企业消息服务账户数',0.891200);
# insert into rsc_sim values('A0043','个人消息服务账户数','A0042','个人消息服务客户数',0.785500);
# insert into rsc_sim values('A0043','个人消息服务账户数','A0047','企业消息服务客户数',0.659200);
# insert into rsc_sim values('A0044','快e付客户数','A0091','企业客户渗透率',0.166400);
# insert into rsc_sim values('A0044','快e付客户数','A0046','企业网银客户数',0.154700);
# insert into rsc_sim values('A0044','快e付客户数','A0039','个人网银客户数',0.154700);
# insert into rsc_sim values('A0046','企业网银客户数','A0039','个人网银客户数',0.726600);
# insert into rsc_sim values('A0046','企业网银客户数','A0091','企业客户渗透率',0.607500);
# insert into rsc_sim values('A0046','企业网银客户数','A0058','企业电话银行客户数',0.565900);
# insert into rsc_sim values('A0047','企业消息服务客户数','A0042','个人消息服务客户数',0.853400);
# insert into rsc_sim values('A0047','企业消息服务客户数','A0048','企业消息服务账户数',0.785500);
# insert into rsc_sim values('A0047','企业消息服务客户数','A0043','个人消息服务账户数',0.659200);
# insert into rsc_sim values('A0048','企业消息服务账户数','A0043','个人消息服务账户数',0.891200);
# insert into rsc_sim values('A0048','企业消息服务账户数','A0047','企业消息服务客户数',0.785500);
# insert into rsc_sim values('A0048','企业消息服务账户数','A0042','个人消息服务客户数',0.659200);
# insert into rsc_sim values('A0052','个人网银活跃客户数','A0092','个人网银动户率',0.899400);
# insert into rsc_sim values('A0052','个人网银活跃客户数','A0054','企业网银活跃客户数',0.809600);
# insert into rsc_sim values('A0052','个人网银活跃客户数','A0053','掌上银行活跃客户数',0.796900);
# insert into rsc_sim values('A0053','掌上银行活跃客户数','A0093','掌上银行动户率',0.907100);
# insert into rsc_sim values('A0053','掌上银行活跃客户数','A0052','个人网银活跃客户数',0.796900);
# insert into rsc_sim values('A0053','掌上银行活跃客户数','A0054','企业网银活跃客户数',0.705000);
# insert into rsc_sim values('A0054','企业网银活跃客户数','A0089','企业客户动户率',0.874200);
# insert into rsc_sim values('A0054','企业网银活跃客户数','A0205','企业网银动户率',0.874200);
# insert into rsc_sim values('A0054','企业网银活跃客户数','A0052','个人网银活跃客户数',0.809600);
# insert into rsc_sim values('A0057','个人电话银行客户数','A0058','企业电话银行客户数',0.842700);
# insert into rsc_sim values('A0057','个人电话银行客户数','A0039','个人网银客户数',0.565900);
# insert into rsc_sim values('A0057','个人电话银行客户数','A0040','掌上银行客户数',0.562800);
# insert into rsc_sim values('A0058','企业电话银行客户数','A0057','个人电话银行客户数',0.842700);
# insert into rsc_sim values('A0058','企业电话银行客户数','A0046','企业网银客户数',0.565900);
# insert into rsc_sim values('A0058','企业电话银行客户数','A0040','掌上银行客户数',0.562800);
# insert into rsc_sim values('A0069','个人网银交易笔数','A0075','企业网银交易笔数',0.905600);
# insert into rsc_sim values('A0069','个人网银交易笔数','A0072','掌上银行交易笔数',0.786300);
# insert into rsc_sim values('A0069','个人网银交易笔数','A0070','个人网银金融性交易笔数',0.763300);
# insert into rsc_sim values('A0070','个人网银金融性交易笔数','A0076','企业网银金融性交易笔数',0.896900);
# insert into rsc_sim values('A0070','个人网银金融性交易笔数','A0071','个人网银交易金额',0.772500);
# insert into rsc_sim values('A0070','个人网银金融性交易笔数','A0073','掌上银行金融性交易笔数',0.767500);
# insert into rsc_sim values('A0071','个人网银交易金额','A0077','企业网银交易金额',0.903300);
# insert into rsc_sim values('A0071','个人网银交易金额','A0074','掌上银行交易金额',0.781400);
# insert into rsc_sim values('A0071','个人网银交易金额','A0070','个人网银金融性交易笔数',0.772500);
# insert into rsc_sim values('A0072','掌上银行交易笔数','A0069','个人网银交易笔数',0.786300);
# insert into rsc_sim values('A0072','掌上银行交易笔数','A0075','企业网银交易笔数',0.786300);
# insert into rsc_sim values('A0072','掌上银行交易笔数','A0073','掌上银行金融性交易笔数',0.782000);
# insert into rsc_sim values('A0073','掌上银行金融性交易笔数','A0074','掌上银行交易金额',0.790700);
# insert into rsc_sim values('A0073','掌上银行金融性交易笔数','A0072','掌上银行交易笔数',0.782000);
# insert into rsc_sim values('A0073','掌上银行金融性交易笔数','A0070','个人网银金融性交易笔数',0.767500);
# insert into rsc_sim values('A0074','掌上银行交易金额','A0073','掌上银行金融性交易笔数',0.790700);
# insert into rsc_sim values('A0074','掌上银行交易金额','A0071','个人网银交易金额',0.781400);
# insert into rsc_sim values('A0074','掌上银行交易金额','A0077','企业网银交易金额',0.781400);
# insert into rsc_sim values('A0075','企业网银交易笔数','A0069','个人网银交易笔数',0.905600);
# insert into rsc_sim values('A0075','企业网银交易笔数','A0072','掌上银行交易笔数',0.786300);
# insert into rsc_sim values('A0075','企业网银交易笔数','A0076','企业网银金融性交易笔数',0.763300);
# insert into rsc_sim values('A0076','企业网银金融性交易笔数','A0070','个人网银金融性交易笔数',0.896900);
# insert into rsc_sim values('A0076','企业网银金融性交易笔数','A0077','企业网银交易金额',0.772500);
# insert into rsc_sim values('A0076','企业网银金融性交易笔数','A0073','掌上银行金融性交易笔数',0.767500);
# insert into rsc_sim values('A0077','企业网银交易金额','A0071','个人网银交易金额',0.903300);
# insert into rsc_sim values('A0077','企业网银交易金额','A0074','掌上银行交易金额',0.781400);
# insert into rsc_sim values('A0077','企业网银交易金额','A0076','企业网银金融性交易笔数',0.772500);
# insert into rsc_sim values('A0088','个人客户动户率','A0093','掌上银行动户率',0.768300);
# insert into rsc_sim values('A0088','个人客户动户率','A0092','个人网银动户率',0.753000);
# insert into rsc_sim values('A0088','个人客户动户率','A0053','掌上银行活跃客户数',0.697500);
# insert into rsc_sim values('A0089','企业客户动户率','A0205','企业网银动户率',1.000000);
# insert into rsc_sim values('A0089','企业客户动户率','A0054','企业网银活跃客户数',0.874200);
# insert into rsc_sim values('A0089','企业客户动户率','A0092','个人网银动户率',0.798400);
# insert into rsc_sim values('A0090','个人客户渗透率','A0091','企业客户渗透率',0.549200);
# insert into rsc_sim values('A0090','个人客户渗透率','A0057','个人电话银行客户数',0.451000);
# insert into rsc_sim values('A0090','个人客户渗透率','A0039','个人网银客户数',0.423800);
# insert into rsc_sim values('A0091','企业客户渗透率','A0046','企业网银客户数',0.607500);
# insert into rsc_sim values('A0091','企业客户渗透率','A0090','个人客户渗透率',0.549200);
# insert into rsc_sim values('A0091','企业客户渗透率','A0206','企业网银活跃客户数计划完成率',0.525700);
# insert into rsc_sim values('A0092','个人网银动户率','A0052','个人网银活跃客户数',0.899400);
# insert into rsc_sim values('A0092','个人网银动户率','A0205','企业网银动户率',0.798400);
# insert into rsc_sim values('A0092','个人网银动户率','A0089','企业客户动户率',0.798400);
# insert into rsc_sim values('A0093','掌上银行动户率','A0053','掌上银行活跃客户数',0.907100);
# insert into rsc_sim values('A0093','掌上银行动户率','A0088','个人客户动户率',0.768300);
# insert into rsc_sim values('A0093','掌上银行动户率','A0092','个人网银动户率',0.745900);
# insert into rsc_sim values('A0112','公共租赁住房贷款','A0116','限价商品住房开发贷款',0.461100);
# insert into rsc_sim values('A0112','公共租赁住房贷款','A0125','农村危房改造不良贷款',0.379500);
# insert into rsc_sim values('A0112','公共租赁住房贷款','A0118','游牧民定居工程贷款',0.339600);
# insert into rsc_sim values('A0114','棚户区及垦区危房改造贷款','A0116','限价商品住房开发贷款',0.152100);
# insert into rsc_sim values('A0114','棚户区及垦区危房改造贷款','A0125','农村危房改造不良贷款',0.146100);
# insert into rsc_sim values('A0114','棚户区及垦区危房改造贷款','A0118','游牧民定居工程贷款',0.145700);
# insert into rsc_sim values('A0115','经济适用住房开发贷款','A0116','限价商品住房开发贷款',0.449600);
# insert into rsc_sim values('A0115','经济适用住房开发贷款','A0119','保障性安居工程不良贷款',0.369200);
# insert into rsc_sim values('A0115','经济适用住房开发贷款','A0112','公共租赁住房贷款',0.226800);
# insert into rsc_sim values('A0116','限价商品住房开发贷款','A0112','公共租赁住房贷款',0.461100);
# insert into rsc_sim values('A0116','限价商品住房开发贷款','A0115','经济适用住房开发贷款',0.449600);
# insert into rsc_sim values('A0116','限价商品住房开发贷款','A0125','农村危房改造不良贷款',0.421900);
# insert into rsc_sim values('A0118','游牧民定居工程贷款','A0126','游牧民定居工程不良贷款',0.890000);
# insert into rsc_sim values('A0118','游牧民定居工程贷款','A0125','农村危房改造不良贷款',0.381900);
# insert into rsc_sim values('A0118','游牧民定居工程贷款','A0116','限价商品住房开发贷款',0.377500);
# insert into rsc_sim values('A0119','保障性安居工程不良贷款','A0125','农村危房改造不良贷款',0.506300);
# insert into rsc_sim values('A0119','保障性安居工程不良贷款','A0126','游牧民定居工程不良贷款',0.464400);
# insert into rsc_sim values('A0119','保障性安居工程不良贷款','A0116','限价商品住房开发贷款',0.381900);
# insert into rsc_sim values('A0125','农村危房改造不良贷款','A0126','游牧民定居工程不良贷款',0.519500);
# insert into rsc_sim values('A0125','农村危房改造不良贷款','A0119','保障性安居工程不良贷款',0.506300);
# insert into rsc_sim values('A0125','农村危房改造不良贷款','A0116','限价商品住房开发贷款',0.421900);
# insert into rsc_sim values('A0126','游牧民定居工程不良贷款','A0118','游牧民定居工程贷款',0.890000);
# insert into rsc_sim values('A0126','游牧民定居工程不良贷款','A0125','农村危房改造不良贷款',0.519500);
# insert into rsc_sim values('A0126','游牧民定居工程不良贷款','A0119','保障性安居工程不良贷款',0.464400);
# insert into rsc_sim values('A0197','电子银行总收入','A0214','掌上银行收入',0.760700);
# insert into rsc_sim values('A0197','电子银行总收入','A0212','个人网银收入',0.269300);
# insert into rsc_sim values('A0197','电子银行总收入','A0213','企业网银收入',0.269300);
# insert into rsc_sim values('A0203','掌上银行活跃客户数计划完成率','A0206','企业网银活跃客户数计划完成率',0.678900);
# insert into rsc_sim values('A0203','掌上银行活跃客户数计划完成率','A0040','掌上银行客户数',0.573300);
# insert into rsc_sim values('A0203','掌上银行活跃客户数计划完成率','A0093','掌上银行动户率',0.565200);
# insert into rsc_sim values('A0205','企业网银动户率','A0205','企业网银动户率',1.000000);
# insert into rsc_sim values('A0205','企业网银动户率','A0054','企业网银活跃客户数',0.874200);
# insert into rsc_sim values('A0205','企业网银动户率','A0092','个人网银动户率',0.798400);
# insert into rsc_sim values('A0206','企业网银活跃客户数计划完成率','A0203','掌上银行活跃客户数计划完成率',0.678900);
# insert into rsc_sim values('A0206','企业网银活跃客户数计划完成率','A0091','企业客户渗透率',0.525700);
# insert into rsc_sim values('A0206','企业网银活跃客户数计划完成率','A0046','企业网银客户数',0.503600);
# insert into rsc_sim values('A0209','批发零售业贷款','A0210','房地产贷款',0.832100);
# insert into rsc_sim values('A0209','批发零售业贷款','A0001','法人贷款',0.295500);
# insert into rsc_sim values('A0209','批发零售业贷款','A0027','本年累计新发放个人贷款加权利率',0.258300);
# insert into rsc_sim values('A0210','房地产贷款','A0209','批发零售业贷款',0.832100);
# insert into rsc_sim values('A0210','房地产贷款','A0001','法人贷款',0.316700);
# insert into rsc_sim values('A0210','房地产贷款','A0027','本年累计新发放个人贷款加权利率',0.276900);
# insert into rsc_sim values('A0212','个人网银收入','A0213','企业网银收入',0.819600);
# insert into rsc_sim values('A0212','个人网银收入','A0215','电子商务收入',0.574300);
# insert into rsc_sim values('A0212','个人网银收入','A0216','消息服务收入',0.553000);
# insert into rsc_sim values('A0213','企业网银收入','A0212','个人网银收入',0.819600);
# insert into rsc_sim values('A0213','企业网银收入','A0215','电子商务收入',0.574300);
# insert into rsc_sim values('A0213','企业网银收入','A0216','消息服务收入',0.553000);
# insert into rsc_sim values('A0214','掌上银行收入','A0197','电子银行总收入',0.760700);
# insert into rsc_sim values('A0214','掌上银行收入','A0212','个人网银收入',0.287200);
# insert into rsc_sim values('A0214','掌上银行收入','A0213','企业网银收入',0.287200);
# insert into rsc_sim values('A0215','电子商务收入','A0212','个人网银收入',0.574300);
# insert into rsc_sim values('A0215','电子商务收入','A0213','企业网银收入',0.574300);
# insert into rsc_sim values('A0215','电子商务收入','A0216','消息服务收入',0.487100);
# insert into rsc_sim values('A0216','消息服务收入','A0042','个人消息服务客户数',0.564400);
# insert into rsc_sim values('A0216','消息服务收入','A0047','企业消息服务客户数',0.564400);
# insert into rsc_sim values('A0216','消息服务收入','A0213','企业网银收入',0.553000);
# insert into rsc_sim values('A0217','转账电话收入','A0218','电话银行及其他收入',0.502700);
# insert into rsc_sim values('A0217','转账电话收入','A0212','个人网银收入',0.425600);
# insert into rsc_sim values('A0217','转账电话收入','A0213','企业网银收入',0.425600);
# insert into rsc_sim values('A0218','电话银行及其他收入','A0217','转账电话收入',0.502700);
# insert into rsc_sim values('A0218','电话银行及其他收入','A0213','企业网银收入',0.467700);
# insert into rsc_sim values('A0218','电话银行及其他收入','A0212','个人网银收入',0.467700);
# insert into rsc_sim values('A0219','K宝客户数','A0220','K令客户数',1.000000);
# insert into rsc_sim values('A0219','K宝客户数','A0039','个人网银客户数',0.742700);
# insert into rsc_sim values('A0219','K宝客户数','A0046','企业网银客户数',0.539700);
# insert into rsc_sim values('A0220','K令客户数','A0220','K令客户数',1.000000);
# insert into rsc_sim values('A0220','K令客户数','A0039','个人网银客户数',0.742700);
# insert into rsc_sim values('A0220','K令客户数','A0046','企业网银客户数',0.539700);
# insert into rsc_sim values('A0221','自助注册客户数','A0039','个人网银客户数',0.584200);
# insert into rsc_sim values('A0221','自助注册客户数','A0219','K宝客户数',0.433900);
# insert into rsc_sim values('A0221','自助注册客户数','A0220','K令客户数',0.433900);
# insert into rsc_sim values('B0001','资产利润率ROA','B0002','资本利润率ROE',0.367600);
# insert into rsc_sim values('B0001','资产利润率ROA','B0222','所得税',0.139000);
# insert into rsc_sim values('B0001','资产利润率ROA','A0205','企业网银动户率',0.090900);
# insert into rsc_sim values('B0002','资本利润率ROE','B0001','资产利润率ROA',0.367600);
# insert into rsc_sim values('B0002','资本利润率ROE','B0222','所得税',0.140600);
# insert into rsc_sim values('B0002','资本利润率ROE','A0003','工资薪金支出',0.051600);
# insert into rsc_sim values('B0004','成本收入比（银监会口径）','B0218','营业外净收入',0.569400);
# insert into rsc_sim values('B0004','成本收入比（银监会口径）','B0006','非利息收入比率',0.466900);
# insert into rsc_sim values('B0004','成本收入比（银监会口径）','B0214','营业税金及附加',0.340700);
# insert into rsc_sim values('B0006','非利息收入比率','B0218','营业外净收入',0.545400);
# insert into rsc_sim values('B0006','非利息收入比率','B0004','成本收入比（银监会口径）',0.466900);
# insert into rsc_sim values('B0006','非利息收入比率','B0201','营业收入',0.347100);
# insert into rsc_sim values('B0201','营业收入','B0006','非利息收入比率',0.347100);
# insert into rsc_sim values('B0201','营业收入','B0205','手续费及佣金净收入',0.336400);
# insert into rsc_sim values('B0201','营业收入','B0211','其他业务收入',0.321000);
# insert into rsc_sim values('B0202','利息净收入','B0203','利息收入',0.349400);
# insert into rsc_sim values('B0202','利息净收入','B0204','利息支出',0.295400);
# insert into rsc_sim values('B0202','利息净收入','B0208','投资收益',0.285000);
# insert into rsc_sim values('B0203','利息收入','B0202','利息净收入',0.349400);
# insert into rsc_sim values('B0203','利息收入','B0204','利息支出',0.183200);
# insert into rsc_sim values('B0203','利息收入','B0208','投资收益',0.149100);
# insert into rsc_sim values('B0204','利息支出','B0202','利息净收入',0.295400);
# insert into rsc_sim values('B0204','利息支出','B0205','手续费及佣金净收入',0.247400);
# insert into rsc_sim values('B0204','利息支出','B0206','手续费及佣金收入',0.193400);
# insert into rsc_sim values('B0205','手续费及佣金净收入','B0206','手续费及佣金收入',0.598000);
# insert into rsc_sim values('B0205','手续费及佣金净收入','B0201','营业收入',0.336400);
# insert into rsc_sim values('B0205','手续费及佣金净收入','B0204','利息支出',0.247400);
# insert into rsc_sim values('B0206','手续费及佣金收入','B0205','手续费及佣金净收入',0.598000);
# insert into rsc_sim values('B0206','手续费及佣金收入','B0207','手续费及佣金支出',0.462400);
# insert into rsc_sim values('B0206','手续费及佣金收入','B0216','其他营业支出',0.237800);
# insert into rsc_sim values('B0207','手续费及佣金支出','B0206','手续费及佣金收入',0.462400);
# insert into rsc_sim values('B0207','手续费及佣金支出','B0201','营业收入',0.234900);
# insert into rsc_sim values('B0207','手续费及佣金支出','B0205','手续费及佣金净收入',0.227700);
# insert into rsc_sim values('B0208','投资收益','B0211','其他业务收入',0.336800);
# insert into rsc_sim values('B0208','投资收益','B0202','利息净收入',0.285000);
# insert into rsc_sim values('B0208','投资收益','B0210','汇兑损益',0.227200);
# insert into rsc_sim values('B0209','公允价值变动损益','B0211','其他业务收入',0.198500);
# insert into rsc_sim values('B0209','公允价值变动损益','B0220','营业外支出',0.165000);
# insert into rsc_sim values('B0209','公允价值变动损益','A0002','国际贸易融资',0.115000);
# insert into rsc_sim values('B0210','汇兑损益','B0213','业务及管理费',0.231900);
# insert into rsc_sim values('B0210','汇兑损益','B0208','投资收益',0.227200);
# insert into rsc_sim values('B0210','汇兑损益','B0211','其他业务收入',0.212900);
# insert into rsc_sim values('B0211','其他业务收入','B0208','投资收益',0.336800);
# insert into rsc_sim values('B0211','其他业务收入','B0201','营业收入',0.321000);
# insert into rsc_sim values('B0211','其他业务收入','B0219','营业外收入',0.292400);
# insert into rsc_sim values('B0212','营业支出','B0216','其他营业支出',0.640500);
# insert into rsc_sim values('B0212','营业支出','B0213','业务及管理费',0.384800);
# insert into rsc_sim values('B0212','营业支出','B0220','营业外支出',0.383900);
# insert into rsc_sim values('B0213','业务及管理费','B0212','营业支出',0.384800);
# insert into rsc_sim values('B0213','业务及管理费','B0210','汇兑损益',0.231900);
# insert into rsc_sim values('B0213','业务及管理费','B0205','手续费及佣金净收入',0.221100);
# insert into rsc_sim values('B0214','营业税金及附加','B0004','成本收入比（银监会口径）',0.340700);
# insert into rsc_sim values('B0214','营业税金及附加','B0006','非利息收入比率',0.246100);
# insert into rsc_sim values('B0214','营业税金及附加','B0218','营业外净收入',0.232400);
# insert into rsc_sim values('B0215','资产减值损失','B0212','营业支出',0.163000);
# insert into rsc_sim values('B0215','资产减值损失','B0216','其他营业支出',0.131900);
# insert into rsc_sim values('B0215','资产减值损失','B0220','营业外支出',0.108100);
# insert into rsc_sim values('B0216','其他营业支出','B0212','营业支出',0.640500);
# insert into rsc_sim values('B0216','其他营业支出','B0220','营业外支出',0.355000);
# insert into rsc_sim values('B0216','其他营业支出','B0004','成本收入比（银监会口径）',0.321000);
# insert into rsc_sim values('B0217','营业利润','B0213','业务及管理费',0.120500);
# insert into rsc_sim values('B0217','营业利润','B0202','利息净收入',0.082900);
# insert into rsc_sim values('B0217','营业利润','B0210','汇兑损益',0.076500);
# insert into rsc_sim values('B0218','营业外净收入','B0004','成本收入比（银监会口径）',0.569400);
# insert into rsc_sim values('B0218','营业外净收入','B0006','非利息收入比率',0.545400);
# insert into rsc_sim values('B0218','营业外净收入','B0214','营业税金及附加',0.232400);
# insert into rsc_sim values('B0219','营业外收入','B0220','营业外支出',0.427200);
# insert into rsc_sim values('B0219','营业外收入','B0211','其他业务收入',0.292400);
# insert into rsc_sim values('B0219','营业外收入','B0210','汇兑损益',0.169600);
# insert into rsc_sim values('B0220','营业外支出','B0219','营业外收入',0.427200);
# insert into rsc_sim values('B0220','营业外支出','B0212','营业支出',0.383900);
# insert into rsc_sim values('B0220','营业外支出','B0216','其他营业支出',0.355000);
# insert into rsc_sim values('B0221','税前利润总额','B0210','汇兑损益',0.195400);
# insert into rsc_sim values('B0221','税前利润总额','A0219','K宝客户数',0.000000);
# insert into rsc_sim values('B0221','税前利润总额','A0218','电话银行及其他收入',0.000000);
# insert into rsc_sim values('B0222','所得税','B0213','业务及管理费',0.170000);
# insert into rsc_sim values('B0222','所得税','B0004','成本收入比（银监会口径）',0.142700);
# insert into rsc_sim values('B0222','所得税','B0002','资本利润率ROE',0.140600);
